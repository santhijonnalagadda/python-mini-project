# %%
import pandas as pd

# %%
datapath=r"C:\Users\santh\OneDrive\Desktop\football.zip"

# %%
df=pd.read_csv(datapath,compression='zip')

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
import random

# %%
age=[]
height=[]
weight=[]

# %%
df.shape
# Out:
# (964, 44)

# %%
#loop comprehension
[age.append(random.randint(18,40)) for _ in range(964)]
print(f"age is now having {len(age)}")
# Out:
# age is now having 964

# %%
age
# Out:
# [25,
#  27,
#  33,
#  26,
#  30,
#  30,
#  31,
#  33,
#  22,
#  19,
#  34,
#  37,
#  38,
#  27,
#  39,
#  35,
#  27,
#  35,
#  35,
#  26,
#  30,
#  18,
#  20,
#  24,
#  25,
#  20,
#  33,
#  25,
#  31,
#  25,
#  26,
#  38,
#  31,
#  23,
#  37,
#  20,
#  28,
#  25,
#  34,
#  34,
#  25,
#  19,
#  21,
#  24,
#  22,
#  20,
#  36,
#  37,
#  37,
#  28,
#  40,
#  23,
#  22,
#  34,
#  40,
#  19,
#  18,
#  19,
#  39,
#  22,
#  37,
#  34,
#  28,
#  31,
#  33,
#  35,
#  37,
#  24,
#  32,
#  33,
#  22,
#  26,
#  32,
#  28,
#  25,
#  24,
#  28,
#  39,
#  24,
#  19,
#  22,
#  25,
#  36,
#  31,
#  18,
#  20,
#  20,
#  32,
#  18,
#  24,
#  35,
#  29,
#  28,
#  37,
#  27,
#  22,
#  21,
#  33,
#  27,
#  40,
#  35,
#  39,
#  40,
#  23,
#  35,
#  21,
#  24,
#  36,
#  21,
#  36,
#  35,
#  27,
#  31,
#  36,
#  22,
#  33,
#  23,
#  20,
#  18,
#  21,
#  37,
#  37,
#  36,
#  34,
#  21,
#  26,
#  18,
#  28,
#  18,
#  20,
#  25,
#  28,
#  28,
#  21,
#  37,
#  37,
#  30,
#  39,
#  33,
#  40,
#  21,
#  30,
# ...

# %%
#adding a new column to the dataframe
#syntax : df['newcolumnname']=list/series of elements
df['yearsofexperience']=age

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
df['ASP']=df['yearsofexperience']-df['home_score']

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
df.shape
# Out:
# (964, 47)

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
df['ASP'].plot()
# Out:
# <Axes: >

# %%
df.plot(x='yearsofexperience',y='ASP',kind='hexbin',color='purple')
# Out:
# <Axes: xlabel='yearsofexperience', ylabel='ASP'>

# %%
df.plot(x='yearsofexperience',y='ASP',kind='scatter',color='purple')
# Out:
# <Axes: xlabel='yearsofexperience', ylabel='ASP'>

# %%
df.plot(x='yearsofexperience',y='ASP',kind='hist',color='purple')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(x='yearsofexperience',y=['ASP','home_score'],kind='bar',color=['yellow','blue'])
# Out:
# <Axes: xlabel='yearsofexperience'>

# %%
df.plot(x='ASP',y=['home_score','away_score'],kind='bar',color=['yellow','blue'])
# Out:
# <Axes: xlabel='ASP'>

# %%
#for scatter we should only use onw variables but not like this
#df.plot(x='ASP',y=['home_score','away_score'],kind='bar',color=['yellow','blue'])  = it is wrong
df.plot(x='ASP',y='home_score',kind='scatter',color='yellow')
# Out:
# <Axes: xlabel='ASP', ylabel='home_score'>

# %%
#function to get a graph
def getgraph(DataFrame,column1,column2):
    from matplotlib import pyplot as plt
    #check the length of column1 and column2
    if len(DataFrame[column1])==len(DataFrame[column2]):
        df.plot(x=column1,y=column2,kind='bar',color=['grey','aquamarine'])
        print('the graph is successfully created')
    else:
        print('please check the column size once')

# %%
getgraph(df,'home_score','away_score')
# Out:
# the graph is successfully created
