# %%
#BASIC DATA ANALYSIS AND VISUALISATION USING PANDAS
#IMPORTING NECESSARY LIBRARIES

import pandas as pd

# %%
#DATA LOADING AND PARSING

path=r"C:\Users\santh\OneDrive\Documents\retailtransactions.csv"

# %%
#READING THE CSV FILE INTO PANDAS DATAFRAME

df=pd.read_csv(path)

# %%
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001        1/1/2024      102        1646        545
# 1           T002        1/2/2024      103        1226        542
# 2           T003        1/3/2024      102        1515        593
# 3           T004        1/4/2024      103        1793        560
# 4           T005        1/5/2024      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096        4/5/2024      101        1918        559
# 96          T097        4/6/2024      104        1190        579
# 97          T098        4/7/2024      102        1932        504
# 98          T099        4/8/2024      103        1285        587
# 99          T100        4/9/2024      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount
# 0      Electronics         1    150      Credit      15.0
# 1             Toys         2    317       Debit      10.0
# ...

# %%
#TRANSACTION DATE IS PARSED INTO DATETIME OBJECT

df['TransactionDate']=pd.to_datetime(df['TransactionDate'])

# %%
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount
# 0      Electronics         1    150      Credit      15.0
# 1             Toys         2    317       Debit      10.0
# ...

# %%
#INITIAL DATA EXPLORATION
#THE SUMMARY OF THE DATAFRAME

df.describe()
# Out:
#            TransactionDate     StoreID   CustomerID   ProductID    Quantity  \
# count                  100  100.000000   100.000000  100.000000  100.000000
# mean   2024-02-19 12:00:00  102.730000  1552.520000  554.390000    5.370000
# min    2024-01-01 00:00:00  101.000000  1013.000000  501.000000    1.000000
# 25%    2024-01-25 18:00:00  101.000000  1310.250000  529.750000    3.000000
# 50%    2024-02-19 12:00:00  103.000000  1534.000000  554.000000    5.500000
# 75%    2024-03-15 06:00:00  104.000000  1800.750000  579.500000    8.000000
# max    2024-04-09 00:00:00  105.000000  1983.000000  600.000000   10.000000
# std                    NaN    1.384291   268.295461   28.544098    3.013957
#
#            Price   Discount
# count  100.00000  75.000000
# mean   282.15000   7.733333
# min     50.00000   0.000000
# 25%    165.75000   2.500000
# 50%    280.00000  10.000000
# 75%    415.25000  12.500000
# max    500.00000  15.000000
# std    140.19938   5.652871

# %%
# DISPLAYING THE FIRST 15 ROWS OF DATAFRAME

first_15_rows=df.head(15)

# %%
first_15_rows
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# 5           T006      2024-01-06      103        1836        515
# 6           T007      2024-01-07      103        1983        586
# 7           T008      2024-01-08      101        1806        569
# 8           T009      2024-01-09      101        1925        548
# 9           T010      2024-01-10      101        1711        565
# 10          T011      2024-01-11      103        1276        565
# 11          T012      2024-01-12      101        1486        523
# 12          T013      2024-01-13      103        1597        516
# ...

# %%
# DISPLAYING THE SUMMARY OF FIRST 15 ROWS OF DATAFRAME

first_15_rows.describe()
# Out:
#            TransactionDate     StoreID   CustomerID   ProductID   Quantity  \
# count                   15   15.000000    15.000000   15.000000  15.000000
# mean   2024-01-08 00:00:00  102.400000  1652.933333  550.066667   5.066667
# min    2024-01-01 00:00:00  101.000000  1226.000000  515.000000   1.000000
# 25%    2024-01-04 12:00:00  101.000000  1500.500000  523.000000   2.500000
# 50%    2024-01-08 00:00:00  103.000000  1668.000000  548.000000   5.000000
# 75%    2024-01-11 12:00:00  103.000000  1821.000000  567.000000   7.500000
# max    2024-01-15 00:00:00  105.000000  1983.000000  593.000000  10.000000
# std                    NaN    1.242118   226.550047   26.523485   3.195235
#
#             Price   Discount
# count   15.000000  10.000000
# mean   286.800000   8.500000
# min    150.000000   0.000000
# 25%    185.500000   5.000000
# 50%    227.000000  10.000000
# 75%    373.500000  13.750000
# max    500.000000  15.000000
# std    126.979301   5.797509

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    100 non-null    object
#  1   TransactionDate  100 non-null    datetime64[ns]
#  2   StoreID          100 non-null    int64
#  3   CustomerID       100 non-null    int64
#  4   ProductID        100 non-null    int64
#  5   ProductCategory  100 non-null    object
#  6   Quantity         100 non-null    int64
#  7   Price            100 non-null    int64
#  8   PaymentType      100 non-null    object
#  9   Discount         75 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 7.9+ KB

# %%
#DATA CLEANING 

df.count()
# Out:
# TransactionID      100
# TransactionDate    100
# StoreID            100
# CustomerID         100
# ProductID          100
# ProductCategory    100
# Quantity           100
# Price              100
# PaymentType        100
# Discount            75
# dtype: int64

# %%
totalrow=df.shape[0]

# %%
totalrow
# Out:
# 100

# %%
missingvalues=totalrow-df.count()

# %%
missingvalues
# Out:
# TransactionID       0
# TransactionDate     0
# StoreID             0
# CustomerID          0
# ProductID           0
# ProductCategory     0
# Quantity            0
# Price               0
# PaymentType         0
# Discount           25
# dtype: int64

# %%
df['Discount'].head(15)
# Out:
# 0     15.0
# 1     10.0
# 2      NaN
# 3     10.0
# 4      0.0
# 5      NaN
# 6      NaN
# 7      0.0
# 8     10.0
# 9      5.0
# 10     NaN
# 11     5.0
# 12    15.0
# 13     NaN
# 14    15.0
# Name: Discount, dtype: float64

# %%
df['Discount'] = df['Discount'].fillna(0)

# %%
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount
# 0      Electronics         1    150      Credit      15.0
# 1             Toys         2    317       Debit      10.0
# ...

# %%
df['Discount'].unique()
# Out:
# array([15., 10.,  0.,  5.])

# %%
#FEATURE ENGINEERING

df['Net_price']=df['Price']*(1-df['Discount']/100)

# %%
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  Net_price
# 0      Electronics         1    150      Credit      15.0     127.50
# ...

# %%
df['Totalsale']=df['Net_price']*df['Quantity']

# %%
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  Net_price  \
# 0      Electronics         1    150      Credit      15.0     127.50
# ...

# %%
#DATA FILTERING

df_filtered=df[df['Totalsale']>=20]

# %%
df_filtered
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  Net_price  \
# 0      Electronics         1    150      Credit      15.0     127.50
# ...

# %%
#DATATYPE CONVERSION

df['PaymentType'] = df['PaymentType'].astype('category')

# %%
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  Net_price  \
# 0      Electronics         1    150      Credit      15.0     127.50
# ...

# %%
df['PaymentType'].dtype
# Out:
# CategoricalDtype(categories=['Cash', 'Credit', 'Debit'], ordered=False, categories_dtype=object)

# %%
#GROUPING AND AGGREGATION

filtered_productquantity_details=df.groupby('ProductCategory')['Quantity'].sum()

# %%
filtered_productquantity_details
# Out:
# ProductCategory
# Apparel        117
# Electronics     78
# Furniture      130
# Grocery         75
# Toys           137
# Name: Quantity, dtype: int64

# %%
filtered_product_totalsale_details=df.groupby('ProductCategory')['Totalsale'].sum()

# %%
filtered_product_totalsale_details
# Out:
# ProductCategory
# Apparel        28055.35
# Electronics    15980.65
# Furniture      39655.55
# Grocery        17585.80
# Toys           44326.35
# Name: Totalsale, dtype: float64

# %%
sorted_product_totalsale_details = filtered_product_totalsale_details.sort_values(ascending=False)

# %%
sorted_product_totalsale_details
# Out:
# ProductCategory
# Toys           44326.35
# Furniture      39655.55
# Apparel        28055.35
# Grocery        17585.80
# Electronics    15980.65
# Name: Totalsale, dtype: float64

# %%
top_3_productcategories=filtered_product_totalsale_details.sort_values(ascending=False).head(3)

# %%
top_3_productcategories
# Out:
# ProductCategory
# Toys         44326.35
# Furniture    39655.55
# Apparel      28055.35
# Name: Totalsale, dtype: float64

# %%
#MULTILEVEL GROUPING

groupingby=df.groupby('StoreID')['ProductCategory']

# %%
groupingby

# %%
#STORE LEVEL INSIGHTS

average_totalsale_per_transaction = df_filtered.groupby(['StoreID', 'ProductCategory'])['Totalsale'].mean()
average_totalsale_per_transaction
# Out:
# StoreID  ProductCategory
# 101      Apparel            1344.550000
#          Electronics        1128.916667
#          Furniture          1317.943750
#          Toys               2227.016667
# 102      Apparel            1452.180000
#          Electronics         591.380000
#          Furniture          2565.900000
#          Grocery             171.900000
#          Toys               1036.557143
# 103      Apparel            1021.950000
#          Electronics         817.666667
#          Furniture          1560.771429
#          Grocery             954.850000
#          Toys               1239.180000
# 104      Apparel             722.000000
#          Electronics         852.333333
#          Furniture          1528.928571
#          Grocery            1118.833333
#          Toys               1367.700000
# 105      Apparel            2398.450000
#          Electronics        2313.500000
#          Furniture          1176.150000
#          Grocery            2047.600000
# ...

# %%
store_top_product_category = df_filtered.groupby(['StoreID', 'ProductCategory'])['Totalsale'].mean().reset_index()
store_top_product_category = store_top_product_category.loc[store_top_product_category.groupby('StoreID')['Totalsale'].idxmax()]

# %%
store_top_product_category
# Out:
#     StoreID ProductCategory    Totalsale
# 3       101            Toys  2227.016667
# 6       102       Furniture  2565.900000
# 11      103       Furniture  1560.771429
# 16      104       Furniture  1528.928571
# 23      105            Toys  4048.000000

# %%
store_top_product_category.describe()
# Out:
#           StoreID    Totalsale
# count    5.000000     5.000000
# mean   103.000000  2386.123333
# std      1.581139  1029.011329
# min    101.000000  1528.928571
# 25%    102.000000  1560.771429
# 50%    103.000000  2227.016667
# 75%    104.000000  2565.900000
# max    105.000000  4048.000000

# %%
#the total revenue generated from all transactions

df['Total_revenue']=df['Net_price']*df['Quantity']

# %%
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  Net_price  \
# 0      Electronics         1    150      Credit      15.0     127.50
# ...

# %%
# the most frequently purchased product 

df['ProductCategory'].mode()
# Out:
# 0    Furniture
# Name: ProductCategory, dtype: object

# %%
#the average transaction amount

df['Net_price'].mean()
# Out:
# np.float64(266.211)

# %%
#filtering the transactions where the total amount  is greater than 200

total_amount_50=df[df['Total_revenue']>200]

# %%
total_amount_50
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# 5           T006      2024-01-06      103        1836        515
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  Net_price  \
# 1             Toys         2    317       Debit      10.0     285.30
# ...

# %%
# the top 3 customers who have spent the most

top_3_customers=df.groupby('CustomerID')['Total_revenue'].sum().sort_values(ascending=False).head(3)

# %%
top_3_customers
# Out:
# CustomerID
# 1734    5375.0
# 1396    4742.0
# 1532    4490.0
# Name: Total_revenue, dtype: float64

# %%
# the alternative code for above line of code using sort values and head 

top_3_customers=df.groupby('CustomerID')['Total_revenue'].nlargest(3)

# %%
top_3_customers
# Out:
# CustomerID
# 1013        70     390.0
# 1082        39    1575.0
# 1135        34     157.0
# 1161        77    2656.8
# 1169        63    1476.0
#                    ...
# 1950        35    2251.8
# 1954        69     981.0
# 1978        45    1759.5
# 1980        94    2163.0
# 1983        6      170.0
# Name: Total_revenue, Length: 100, dtype: float64
