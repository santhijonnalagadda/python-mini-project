# %%
#manipulating data using pandas and random moduule
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ds=pd.read_csv('/Credit_Card_Applications.csv')

# %%
ds
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# 0    100  1213      0
# 1    160     1      0
# 2    280     1      0
# 3      0     1      1
# 4     60   159      1
# ..   ...   ...    ...
# 685    0     1      1
# 686    0    45      0
# 687  100     1      1
# 688  120    12      1
# 689  560     1      1
#
# [690 rows x 16 columns]

# %%
import pandas as pd
import random
age=[]
height=[]
weight=[]
speed=[]
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))
idata={'Age':age,'Height':height,'Weight':weight,'Speed':speed}

# %%
idata
# Out:
# {'Age': [22,
#   72,
#   37,
#   77,
#   85,
#   71,
#   79,
#   44,
#   16,
#   83,
#   63,
#   43,
#   83,
#   66,
#   86,
#   9,
#   57,
#   10,
#   41,
#   28,
#   31,
#   96,
#   52,
#   7,
#   99,
#   69,
#   45,
#   24,
#   54,
#   86,
#   93,
#   84,
#   39,
#   0,
#   25,
#   89,
#   80,
#   94,
#   9,
#   85,
#   8,
#   48,
#   39,
#   45,
#   4,
#   21,
#   49,
#   21,
#   13,
#   90,
#   10,
#   24,
#   86,
#   2,
#   45,
#   15,
#   24,
#   24,
#   59,
#   55,
#   49,
#   45,
#   57,
#   75,
#   33,
#   30,
#   10,
#   72,
#   1,
#   5,
#   17,
#   30,
#   26,
#   35,
#   79,
#   36,
#   88,
#   92,
#   64,
#   89,
#   4,
#   44,
#   23,
#   9,
#   16,
#   84,
#   96,
#   47,
#   6,
#   97,
#   53,
#   7,
#   77,
#   43,
#   93,
#   17,
#   90,
#   83,
#   35,
#   19],
#  'Height': [20,
#   12,
#   83,
#   76,
#   16,
#   48,
#   86,
#   42,
#   83,
#   69,
#   22,
#   75,
#   6,
#   93,
#   62,
#   73,
#   23,
#   7,
#   4,
#   35,
#   89,
#   96,
#   5,
#   74,
#   7,
#   14,
#   18,
#   24,
#   84,
#   3,
#   47,
#   63,
#   71,
#   53,
#   77,
#   99,
#   64,
#   79,
#   26,
#   48,
#   18,
#   20,
#   70,
#   52,
#   7,
#   15,
#   1,
#   81,
#   62,
#   92,
#   37,
#   9,
#   88,
#   31,
#   72,
#   39,
#   53,
#   74,
#   45,
#   97,
#   15,
#   78,
#   92,
#   93,
#   97,
#   14,
#   45,
#   46,
#   35,
#   68,
#   3,
#   81,
#   100,
#   93,
#   51,
#   95,
#   15,
#   67,
#   14,
#   16,
#   3,
#   16,
#   13,
#   21,
#   10,
#   19,
#   2,
#   34,
#   78,
#   76,
#   6,
#   91,
#   62,
#   93,
#   80,
#   31,
#   93,
#   13,
#   46,
#   14],
#  'Weight': [97,
#   71,
#   92,
#   57,
#   72,
#   24,
#   71,
#   48,
#   68,
#   91,
#   48,
#   53,
#   97,
#   41,
#   4,
#   39,
#   86,
#   6,
#   46,
#   21,
#   95,
#   60,
#   48,
#   81,
#   85,
#   13,
#   10,
#   18,
#   85,
#   36,
#   26,
#   42,
#   50,
#   3,
#   29,
#   46,
#   56,
#   6,
#   35,
#   22,
#   24,
#   96,
#   20,
#   63,
#   98,
#   80,
#   1,
#   3,
#   48,
#   84,
#   28,
#   10,
#   6,
#   68,
#   83,
#   57,
#   48,
#   51,
#   56,
#   21,
#   23,
#   16,
#   98,
#   48,
#   96,
#   56,
#   90,
#   94,
#   25,
#   96,
#   21,
#   72,
#   34,
#   34,
#   82,
#   12,
#   12,
#   10,
#   55,
#   51,
#   37,
#   87,
#   20,
#   63,
#   49,
#   78,
#   26,
#   84,
#   91,
#   44,
#   65,
#   52,
#   15,
#   99,
#   18,
#   62,
#   0,
#   58,
#   51,
#   48],
#  'Speed': [96,
#   49,
#   29,
#   73,
#   55,
#   41,
#   73,
#   30,
#   86,
#   35,
#   29,
#   77,
#   46,
#   40,
#   36,
#   31,
#   3,
#   92,
#   61,
#   72,
#   75,
#   8,
#   12,
#   42,
#   24,
#   41,
#   5,
#   21,
#   45,
#   55,
#   30,
#   4,
#   40,
#   93,
#   32,
#   56,
#   31,
#   0,
#   2,
#   75,
#   0,
#   100,
#   4,
#   82,
#   68,
#   49,
#   37,
#   57,
#   78,
#   75,
#   72,
#   95,
#   21,
#   84,
#   59,
#   74,
#   86,
#   65,
#   41,
#   78,
#   23,
#   96,
#   57,
#   1,
#   33,
#   26,
#   82,
#   17,
#   89,
#   77,
#   7,
#   77,
#   64,
#   47,
#   90,
#   100,
#   74,
#   6,
#   22,
#   56,
#   61,
#   70,
#   91,
#   53,
#   75,
#   43,
#   38,
#   90,
#   29,
#   58,
#   11,
#   9,
#   0,
#   50,
#   5,
#   34,
#   15,
#   26,
#   49,
#   36]}

# %%
df1=pd.DataFrame(idata)

# %%
df1
# Out:
#     Age  Height  Weight  Speed
# 0    18      47      68     93
# 1    79       5      32     10
# 2    41      94       0     48
# 3    75      31      52     69
# 4    14      99      68     27
# ..  ...     ...     ...    ...
# 95   70      21      24      4
# 96   28      69      83     87
# 97   59      21      17     57
# 98   15       3      39     49
# 99   54      29       7     35
#
# [100 rows x 4 columns]

# %%
df1.head(10)
# Out:
#    Age  Height  Weight  Speed
# 0   18      47      68     93
# 1   79       5      32     10
# 2   41      94       0     48
# 3   75      31      52     69
# 4   14      99      68     27
# 5   85      24      84     19
# 6   78      97      32     84
# 7   89      81      89     83
# 8   57       0      39     88
# 9   11      87      83     14

# %%
df1.tail(10)
# Out:
#     Age  Height  Weight  Speed
# 90   99      19       5     85
# 91   72      83      41     31
# 92   12      45       0     67
# 93   28      39      41      7
# 94   59      65      13     40
# 95   70      21      24      4
# 96   28      69      83     87
# 97   59      21      17     57
# 98   15       3      39     49
# 99   54      29       7     35

# %%
df1.describe()
# Out:
#               Age     Height      Weight      Speed
# count  100.000000  100.00000  100.000000  100.00000
# mean    47.920000   50.00000   48.320000   49.45000
# std     30.942658   31.40128   28.731737   29.33966
# min      0.000000    0.00000    0.000000    0.00000
# 25%     21.000000   20.75000   25.000000   23.75000
# 50%     44.500000   50.50000   52.000000   48.00000
# 75%     78.250000   81.25000   71.000000   73.50000
# max    100.000000   99.00000   99.000000   99.00000

# %%
df1[['Age','Height']]
# Out:
#     Age  Height
# 0    18      47
# 1    79       5
# 2    41      94
# 3    75      31
# 4    14      99
# ..  ...     ...
# 95   70      21
# 96   28      69
# 97   59      21
# 98   15       3
# 99   54      29
#
# [100 rows x 2 columns]

# %%
df1.loc[0:3,['Age','Height']]
# Out:
#    Age  Height
# 0   18      47
# 1   79       5
# 2   41      94
# 3   75      31

# %%
df2=df1[['Age','Height']]

# %%
df2
# Out:
#     Age  Height
# 0    18      47
# 1    79       5
# 2    41      94
# 3    75      31
# 4    14      99
# ..  ...     ...
# 95   70      21
# 96   28      69
# 97   59      21
# 98   15       3
# 99   54      29
#
# [100 rows x 2 columns]

# %%
df2.describe()
# Out:
#               Age     Height
# count  100.000000  100.00000
# mean    47.920000   50.00000
# std     30.942658   31.40128
# min      0.000000    0.00000
# 25%     21.000000   20.75000
# 50%     44.500000   50.50000
# 75%     78.250000   81.25000
# max    100.000000   99.00000

# %%
df1.sort_index()
# Out:
#     Age  Height  Weight  Speed
# 0    18      47      68     93
# 1    79       5      32     10
# 2    41      94       0     48
# 3    75      31      52     69
# 4    14      99      68     27
# ..  ...     ...     ...    ...
# 95   70      21      24      4
# 96   28      69      83     87
# 97   59      21      17     57
# 98   15       3      39     49
# 99   54      29       7     35
#
# [100 rows x 4 columns]

# %%
df1.sort_index(ascending=False)
# Out:
#     Age  Height  Weight  Speed
# 99   54      29       7     35
# 98   15       3      39     49
# 97   59      21      17     57
# 96   28      69      83     87
# 95   70      21      24      4
# ..  ...     ...     ...    ...
# 4    14      99      68     27
# 3    75      31      52     69
# 2    41      94       0     48
# 1    79       5      32     10
# 0    18      47      68     93
#
# [100 rows x 4 columns]

# %%
df1.sort_index(ascending=True)
# Out:
#     Age  Height  Weight  Speed
# 0    18      47      68     93
# 1    79       5      32     10
# 2    41      94       0     48
# 3    75      31      52     69
# 4    14      99      68     27
# ..  ...     ...     ...    ...
# 95   70      21      24      4
# 96   28      69      83     87
# 97   59      21      17     57
# 98   15       3      39     49
# 99   54      29       7     35
#
# [100 rows x 4 columns]

# %%
df2[0::2]
# Out:
#     Age  Height
# 0    18      47
# 2    41      94
# 4    14      99
# 6    78      97
# 8    57       0
# 10   58      18
# 12   41      37
# 14   12      11
# 16   15       8
# 18   58      24
# 20   89       7
# 22   36      84
# 24   17      84
# 26   80      67
# 28   23      42
# 30   81      58
# 32   17      51
# 34   40      39
# 36   30       5
# 38   66      94
# 40   40      97
# 42   34      98
# 44   33      57
# 46   91      82
# 48    2      94
# 50   44      63
# 52   29      82
# 54   66      58
# 56   32       4
# 58    1      60
# 60   70      18
# 62   70       9
# 64    4      80
# 66    0      26
# 68   83      68
# 70   23       9
# 72   99      67
# 74   90      12
# 76   87      87
# 78   11       5
# 80   25      18
# 82   46      17
# 84   16      18
# 86    5      29
# 88   42      43
# 90   99      19
# 92   12      45
# 94   59      65
# 96   28      69
# 98   15       3

# %%
df2[0::2].describe()
# Out:
#              Age     Height
# count  50.000000  50.000000
# mean   42.540000  47.360000
# std    29.382912  32.650756
# min     0.000000   0.000000
# 25%    17.000000  18.000000
# 50%    38.000000  46.000000
# 75%    66.000000  77.250000
# max    99.000000  99.000000

# %%
#filter
df1['Weight']>50
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4      True
#       ...
# 95    False
# 96     True
# 97    False
# 98    False
# 99    False
# Name: Weight, Length: 100, dtype: bool

# %%
filter1=df1['Weight']>50

# %%
df1[filter1]
# Out:
#     Age  Height  Weight  Speed
# 0    18      47      68     93
# 3    75      31      52     69
# 4    14      99      68     27
# 5    85      24      84     19
# 7    89      81      89     83
# 9    11      87      83     14
# 10   58      18      62     38
# 11   84      98      85     53
# 12   41      37      65     44
# 13    7      54      86      0
# 15   79      84      60     40
# 16   15       8      95     86
# 17   43      59      74     32
# 18   58      24      84     15
# 20   89       7      61     63
# 23   54      95      72     31
# 25   45       0      62     56
# 27   22      31      66      4
# 29    2      45      62     75
# 30   81      58      97     64
# 33   49      63      70      1
# 35   97      60      85     58
# 36   30       5      72     39
# 38   66      94      99     72
# 39   90      78      56     22
# 43   31      63      71     42
# 45    2      79      89     19
# 46   91      82      66     90
# 47   94       3      54     70
# 52   29      82      90     59
# 53   82      18      69     48
# 54   66      58      68     99
# 55   95      97      61      9
# 56   32       4      55      1
# 57   87      97      92     81
# 59    7      85      70     99
# 61   38      26      55     13
# 62   70       9      56     23
# 66    0      26      78     50
# 68   83      68      86     36
# 69   63      89      58     87
# 75   22      14      97     83
# 78   11       5      77     53
# 80   25      18      60     75
# 81   33      65      71     95
# 83   72      12      87      6
# 84   16      18      78     72
# 86    5      29      72     15
# 87   13      23      70     27
# 89   96      42      52     73
# 96   28      69      83     87

# %%
# loc is more preferable than direct call
df1.loc[filter1]
# Out:
#     Age  Height  Weight  Speed
# 0    18      47      68     93
# 3    75      31      52     69
# 4    14      99      68     27
# 5    85      24      84     19
# 7    89      81      89     83
# 9    11      87      83     14
# 10   58      18      62     38
# 11   84      98      85     53
# 12   41      37      65     44
# 13    7      54      86      0
# 15   79      84      60     40
# 16   15       8      95     86
# 17   43      59      74     32
# 18   58      24      84     15
# 20   89       7      61     63
# 23   54      95      72     31
# 25   45       0      62     56
# 27   22      31      66      4
# 29    2      45      62     75
# 30   81      58      97     64
# 33   49      63      70      1
# 35   97      60      85     58
# 36   30       5      72     39
# 38   66      94      99     72
# 39   90      78      56     22
# 43   31      63      71     42
# 45    2      79      89     19
# 46   91      82      66     90
# 47   94       3      54     70
# 52   29      82      90     59
# 53   82      18      69     48
# 54   66      58      68     99
# 55   95      97      61      9
# 56   32       4      55      1
# 57   87      97      92     81
# 59    7      85      70     99
# 61   38      26      55     13
# 62   70       9      56     23
# 66    0      26      78     50
# 68   83      68      86     36
# 69   63      89      58     87
# 75   22      14      97     83
# 78   11       5      77     53
# 80   25      18      60     75
# 81   33      65      71     95
# 83   72      12      87      6
# 84   16      18      78     72
# 86    5      29      72     15
# 87   13      23      70     27
# 89   96      42      52     73
# 96   28      69      83     87

# %%
filter2=df1['Age']>50

# %%
#using logical and conditional operators
df1[filter1 & filter2]
# Out:
#     Age  Height  Weight  Speed
# 3    75      31      52     69
# 5    85      24      84     19
# 7    89      81      89     83
# 10   58      18      62     38
# 11   84      98      85     53
# 15   79      84      60     40
# 18   58      24      84     15
# 20   89       7      61     63
# 23   54      95      72     31
# 30   81      58      97     64
# 35   97      60      85     58
# 38   66      94      99     72
# 39   90      78      56     22
# 46   91      82      66     90
# 47   94       3      54     70
# 53   82      18      69     48
# 54   66      58      68     99
# 55   95      97      61      9
# 57   87      97      92     81
# 62   70       9      56     23
# 68   83      68      86     36
# 69   63      89      58     87
# 83   72      12      87      6
# 89   96      42      52     73

# %%
df1.loc[filter1 & filter2]
# Out:
#     Age  Height  Weight  Speed
# 3    75      31      52     69
# 5    85      24      84     19
# 7    89      81      89     83
# 10   58      18      62     38
# 11   84      98      85     53
# 15   79      84      60     40
# 18   58      24      84     15
# 20   89       7      61     63
# 23   54      95      72     31
# 30   81      58      97     64
# 35   97      60      85     58
# 38   66      94      99     72
# 39   90      78      56     22
# 46   91      82      66     90
# 47   94       3      54     70
# 53   82      18      69     48
# 54   66      58      68     99
# 55   95      97      61      9
# 57   87      97      92     81
# 62   70       9      56     23
# 68   83      68      86     36
# 69   63      89      58     87
# 83   72      12      87      6
# 89   96      42      52     73

# %%
df1[filter1 | filter2]
# Out:
#     Age  Height  Weight  Speed
# 0    18      47      68     93
# 1    79       5      32     10
# 3    75      31      52     69
# 4    14      99      68     27
# 5    85      24      84     19
# ..  ...     ...     ...    ...
# 94   59      65      13     40
# 95   70      21      24      4
# 96   28      69      83     87
# 97   59      21      17     57
# 99   54      29       7     35
#
# [73 rows x 4 columns]
